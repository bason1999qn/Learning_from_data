# %% [markdown]
# # Bài tập 1
#
# Họ và tên - MSSV

# %% [markdown]
# ## Câu 1 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 2 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 3 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 4 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 5 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 6 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 7 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 8 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 9 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Câu 10 (1 điểm)

# %% [markdown]
# YOUR ANSWER HERE
